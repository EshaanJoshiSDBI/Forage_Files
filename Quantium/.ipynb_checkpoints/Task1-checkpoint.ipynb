# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
import nltk
import re
sns.set(rc={'figure.figsize':(16,9)})

# %% [markdown]
# # Importing data

# %% [markdown]
# ## Customer data

# %%
df_cust = pd.read_csv('QVI_purchase_behaviour.csv')

# %%
df_cust_copy = df_cust.copy()

# %%
df_cust.head()
# Out:
#    LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER
# 0            1000   YOUNG SINGLES/COUPLES          Premium
# 1            1002   YOUNG SINGLES/COUPLES       Mainstream
# 2            1003          YOUNG FAMILIES           Budget
# 3            1004   OLDER SINGLES/COUPLES       Mainstream
# 4            1005  MIDAGE SINGLES/COUPLES       Mainstream

# %%
df_cust.isnull().sum()
# Out:
# LYLTY_CARD_NBR      0
# LIFESTAGE           0
# PREMIUM_CUSTOMER    0
# dtype: int64

# %%
df_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72637 entries, 0 to 72636
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LYLTY_CARD_NBR    72637 non-null  int64
#  1   LIFESTAGE         72637 non-null  object
#  2   PREMIUM_CUSTOMER  72637 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.7+ MB

# %%
df_cust.describe()
# Out:
#        LYLTY_CARD_NBR
# count    7.263700e+04
# mean     1.361859e+05
# std      8.989293e+04
# min      1.000000e+03
# 25%      6.620200e+04
# 50%      1.340400e+05
# 75%      2.033750e+05
# max      2.373711e+06

# %%
df_cust.drop(df_cust[df_cust['LYLTY_CARD_NBR'] == 226000].index,inplace=True)

# %%
df_cust['LIFESTAGE'].value_counts()
# Out:
# RETIREES                  14805
# OLDER SINGLES/COUPLES     14609
# YOUNG SINGLES/COUPLES     14441
# OLDER FAMILIES             9779
# YOUNG FAMILIES             9178
# MIDAGE SINGLES/COUPLES     7275
# NEW FAMILIES               2549
# Name: LIFESTAGE, dtype: int64

# %%
prem_custs = pd.DataFrame(df_cust['PREMIUM_CUSTOMER'].value_counts().reset_index()).rename(columns={'PREMIUM_CUSTOMER':'Count','index':'PREMIUM_CUSTOMER'})

# %%
sns.countplot(y = 'LIFESTAGE',data = df_cust)
# Out:
# <AxesSubplot: xlabel='count', ylabel='LIFESTAGE'>

# %%
plt.pie(prem_custs['Count'],labels=prem_custs['PREMIUM_CUSTOMER'],autopct='%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f90f4491930>,
# ...
#  [Text(0.33128302845960766, 1.0489287654815416, 'Mainstream'),
#   Text(-0.9921483905603237, -0.47501744295189796, 'Budget'),
#   Text(0.7517648941126204, -0.8030252449206319, 'Premium')],
#  [Text(0.1806998337052405, 0.5721429629899317, '40%'),
#   Text(-0.5411718493965401, -0.25910042342830797, '34%'),
#   Text(0.4100535786068838, -0.43801376995670827, '26%')])

# %% [markdown]
# - Most customers are from Retirees group, followed by Young singles/couples and Old singles/couples.

# %% [markdown]
# ## Transaction data

# %%
df_trns = pd.read_excel('QVI_transaction_data.xlsx')

# %%
df_trns_copy = df_trns.copy()

# %%
df_trns.head()
# Out:
#     DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0  43390          1            1000       1         5
# 1  43599          1            1307     348        66
# 2  43605          1            1343     383        61
# 3  43329          2            2373     974        69
# 4  43330          2            2426    1038       108
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES
# 0    Natural Chip        Compny SeaSalt175g         2        6.0
# 1                  CCs Nacho Cheese    175g         3        6.3
# 2    Smiths Crinkle Cut  Chips Chicken 170g         2        2.9
# 3    Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# 4  Kettle Tortilla ChpsHny&Jlpno Chili 150g         3       13.8

# %%
df_trns.isnull().sum()
# Out:
# DATE              0
# STORE_NBR         0
# LYLTY_CARD_NBR    0
# TXN_ID            0
# PROD_NBR          0
# PROD_NAME         0
# PROD_QTY          0
# TOT_SALES         0
# dtype: int64

# %%
df_trns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264836 entries, 0 to 264835
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DATE            264836 non-null  int64
#  1   STORE_NBR       264836 non-null  int64
#  2   LYLTY_CARD_NBR  264836 non-null  int64
#  3   TXN_ID          264836 non-null  int64
#  4   PROD_NBR        264836 non-null  int64
#  5   PROD_NAME       264836 non-null  object
#  6   PROD_QTY        264836 non-null  int64
#  7   TOT_SALES       264836 non-null  float64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 16.2+ MB

# %%
df_trns.describe()
# Out:
#                 DATE     STORE_NBR  LYLTY_CARD_NBR        TXN_ID  \
# count  264836.000000  264836.00000    2.648360e+05  2.648360e+05
# mean    43464.036260     135.08011    1.355495e+05  1.351583e+05
# std       105.389282      76.78418    8.057998e+04  7.813303e+04
# min     43282.000000       1.00000    1.000000e+03  1.000000e+00
# 25%     43373.000000      70.00000    7.002100e+04  6.760150e+04
# 50%     43464.000000     130.00000    1.303575e+05  1.351375e+05
# 75%     43555.000000     203.00000    2.030942e+05  2.027012e+05
# max     43646.000000     272.00000    2.373711e+06  2.415841e+06
#
#             PROD_NBR       PROD_QTY      TOT_SALES
# count  264836.000000  264836.000000  264836.000000
# mean       56.583157       1.907309       7.304200
# std        32.826638       0.643654       3.083226
# min         1.000000       1.000000       1.500000
# 25%        28.000000       2.000000       5.400000
# 50%        56.000000       2.000000       7.400000
# ...

# %%
df_trns['PROD_NAME'].value_counts()
# Out:
# Kettle Mozzarella   Basil & Pesto 175g      3304
# Kettle Tortilla ChpsHny&Jlpno Chili 150g    3296
# Cobs Popd Swt/Chlli &Sr/Cream Chips 110g    3269
# Tyrrells Crisps     Ched & Chives 165g      3268
# Cobs Popd Sea Salt  Chips 110g              3265
#                                             ...
# RRD Pc Sea Salt     165g                    1431
# Woolworths Medium   Salsa 300g              1430
# NCC Sour Cream &    Garden Chives 175g      1419
# French Fries Potato Chips 175g              1418
# WW Crinkle Cut      Original 175g           1410
# Name: PROD_NAME, Length: 114, dtype: int64

# %%
df_trns['PROD_QTY'].value_counts()
# Out:
# 2      236039
# 1       27518
# 5         450
# 3         430
# 4         397
# 200         2
# Name: PROD_QTY, dtype: int64

# %%
df_trns.loc[df_trns['PROD_QTY'] == 200,:]
# Out:
#         DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 69762  43331        226          226000  226201         4
# 69763  43605        226          226000  226210         4
#
#                               PROD_NAME  PROD_QTY  TOT_SALES
# 69762  Dorito Corn Chp     Supreme 380g       200      650.0
# 69763  Dorito Corn Chp     Supreme 380g       200      650.0

# %% [markdown]
# - Probably a commercial purchase

# %%
df_trns.drop(df_trns[df_trns['PROD_QTY'] == 200].index,inplace=True)

# %%
df_trns.loc[df_trns['PROD_QTY'] == 200,:]
# Out:
# Empty DataFrame
# Columns: [DATE, STORE_NBR, LYLTY_CARD_NBR, TXN_ID, PROD_NBR, PROD_NAME, PROD_QTY, TOT_SALES]
# Index: []

# %%
def date_format(date):
    anc = dt.datetime(1900,1,1)
    if date < 60:
        dd = dt.timedelta(days=date-1)
    else:
        dd = dt.timedelta(days=date-2)
    return anc + dd

# %%
df_trns['DATE'] = df_trns['DATE'].apply(date_format)

# %%
len(df_trns) == df_trns.TXN_ID.nunique()
# Out:
# False

# %%
df_trns[df_trns.duplicated('TXN_ID')].head()
# Out:
#           DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 42  2019-05-20         55           55073   48887       113
# 377 2019-01-10          7            7364    7739        20
# 419 2018-10-18         12           12301   10982        93
# 476 2018-09-08         16           16427   14546        81
# 511 2018-08-03         19           19272   16683        31
#
#                                    PROD_NAME  PROD_QTY  TOT_SALES
# 42                      Twisties Chicken270g         1        4.6
# 377         Doritos Cheese      Supreme 330g         2       11.4
# 419  Doritos Corn Chip Southern Chicken 150g         2        7.8
# 476          Pringles Original   Crisps 134g         1        3.7
# 511   Infzns Crn Crnchers Tangy Gcamole 110g         2        7.6

# %%
df_trns.loc[df_trns['TXN_ID'] == 7739,:]
# Out:
#           DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 376 2019-01-10          7            7364    7739        50
# 377 2019-01-10          7            7364    7739        20
#
#                             PROD_NAME  PROD_QTY  TOT_SALES
# 376   Tostitos Lightly    Salted 175g         2        8.8
# 377  Doritos Cheese      Supreme 330g         2       11.4

# %%
df_trns['PROD_SIZE'] = df_trns['PROD_NAME'].str.extract('(\d+)')
df_trns['PROD_SIZE'] = pd.to_numeric(df_trns['PROD_SIZE'])

# %%
def process_txt(txt):
    txt = re.sub('\d\w*',' ',txt)
    txt = re.sub('[&/]',' ',txt)
    return txt

# %%
df_trns['PROD_NAME'] = df_trns['PROD_NAME'].apply(process_txt)

# %%
df_trns['BRAND'] = df_trns['PROD_NAME'].str.partition()[0]

# %%
prod_name = ''.join(df_trns['PROD_NAME'])
prod_names = nltk.word_tokenize(prod_name)

# %%
pd.DataFrame(list(nltk.probability.FreqDist(prod_names).items()),columns=['Word','Frequency']).sort_values(by='Frequency',ascending=False).head()
# Out:
#         Word  Frequency
# 10     Chips      49770
# 16    Kettle      40739
# 7     Smiths      28572
# 6     Cheese      27890
# 66  Pringles      24743

# %%
grp_sales = df_trns.groupby('DATE')[['TOT_SALES']].sum()

# %%
grp_sales.loc['2018-12-25'] = 0

# %%
grp_sales.reset_index(inplace=True)
# Out:
# /tmp/ipykernel_9812/949551136.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   grp_sales.reset_index(inplace=True)

# %%
grp_sales.head()
# Out:
#         DATE  TOT_SALES
# 0 2018-07-01     5372.2
# 1 2018-07-02     5315.4
# 2 2018-07-03     5321.8
# 3 2018-07-04     5309.9
# 4 2018-07-05     5080.9

# %%
sns.lineplot(data=grp_sales,x='DATE',y='TOT_SALES')
# Out:
# <AxesSubplot: xlabel='DATE', ylabel='TOT_SALES'>

# %% [markdown]
# - Stores closed on Christmas, hence sales are zero on 2018-12-25

# %%
sns.countplot(data=df_trns,y='PROD_SIZE')
# Out:
# <AxesSubplot: xlabel='count', ylabel='PROD_SIZE'>

# %%
brands = {'Ncc':'Natural',
         'NCC':'Natural',
         'Ccs':'CCS',
         'CCs':'CCS',
         'Smith':'Smiths',
         'Grain':'Grainwaves',
         'Grnwves':'Grainwaves',
         'GrnWves':'Grainwaves',
         'Ww':'Woolworths',
         'WW':'Woolworths',
         'Infzns':'Infuzions',
         'Red':'Red Rock Deli',
         'Rrd':'Red Rock Deli',
         'RRD':'Red Rock Deli',
         'Snbts':'Sunbites'}
df_trns['BRAND'] = df_trns['BRAND'].map(brands).fillna(df_trns['BRAND'])

# %%
df_trns['BRAND'].unique()
# Out:
# array(['Natural', 'CCS', 'Smiths', 'Kettle', 'Old', 'Grainwaves',
#        'Doritos', 'Twisties', 'Woolworths', 'Thins', 'Burger', 'Cheezels',
#        'Infuzions', 'Red Rock Deli', 'Pringles', 'Dorito', 'Tyrrells',
#        'Cobs', 'French', 'Tostitos', 'Cheetos', 'Sunbites'], dtype=object)

# %%
brand_df = df_trns.groupby('BRAND')['TOT_SALES'].sum().reset_index().sort_values(by = 'TOT_SALES', ascending=False)

# %%
brand_df.head()
# Out:
#         BRAND  TOT_SALES
# 10     Kettle   390239.8
# 15     Smiths   224660.2
# 6     Doritos   201538.9
# 13   Pringles   177655.5
# 9   Infuzions    99047.6

# %% [markdown]
# # Customer segments

# %%
merged_df = pd.merge(df_cust,df_trns)

# %%
segment_sales = merged_df.groupby(['PREMIUM_CUSTOMER','LIFESTAGE'])['TOT_SALES'].sum().reset_index()

# %%
segment_sales.head()
# Out:
#   PREMIUM_CUSTOMER               LIFESTAGE  TOT_SALES
# 0           Budget  MIDAGE SINGLES/COUPLES   35514.80
# 1           Budget            NEW FAMILIES   21928.45
# 2           Budget          OLDER FAMILIES  168363.25
# 3           Budget   OLDER SINGLES/COUPLES  136769.80
# 4           Budget                RETIREES  113147.80

# %%
sns.barplot(data=segment_sales,x='LIFESTAGE', y='TOT_SALES', hue='PREMIUM_CUSTOMER')
# Out:
# <AxesSubplot: xlabel='LIFESTAGE', ylabel='TOT_SALES'>

# %% [markdown]
# **Most sales come from**
# - Budget Older families
# - Mainstream young singles/couples
# - Mainstream retirees

# %%
segment_qty = merged_df.groupby(['PREMIUM_CUSTOMER','LIFESTAGE'])['PROD_QTY'].sum().reset_index()

# %%
segment_qty.head()
# Out:
#   PREMIUM_CUSTOMER               LIFESTAGE  PROD_QTY
# 0           Budget  MIDAGE SINGLES/COUPLES      9496
# 1           Budget            NEW FAMILIES      5571
# 2           Budget          OLDER FAMILIES     45065
# 3           Budget   OLDER SINGLES/COUPLES     35220
# 4           Budget                RETIREES     28764

# %%
sns.barplot(data=segment_qty,x='LIFESTAGE', y='PROD_QTY', hue='PREMIUM_CUSTOMER')
# Out:
# <AxesSubplot: xlabel='LIFESTAGE', ylabel='PROD_QTY'>

# %% [markdown]
# **Most quantity sold**
# - Budget older families
# - Mainstream retirees
# - Mainstream young singles/couples

# %%
segment_custs = merged_df.groupby(['PREMIUM_CUSTOMER','LIFESTAGE'])['LYLTY_CARD_NBR'].nunique().reset_index()

# %%
sns.barplot(data=segment_custs,x='LIFESTAGE',y='LYLTY_CARD_NBR',hue='PREMIUM_CUSTOMER')
# Out:
# <AxesSubplot: xlabel='LIFESTAGE', ylabel='LYLTY_CARD_NBR'>

# %% [markdown]
# **Most number of customers**
# - Mainstream young singles/couples
# - Mainstream retirees

# %%
segment_avg_units = merged_df.groupby(['PREMIUM_CUSTOMER','LIFESTAGE'])['PROD_QTY'].sum() / merged_df.groupby(['PREMIUM_CUSTOMER','LIFESTAGE'])['LYLTY_CARD_NBR'].nunique()

# %%
segment_avg_units = pd.DataFrame(segment_avg_units,columns=['Average unit per customer'])

# %%
segment_avg_units.reset_index(inplace=True)

# %%
sns.barplot(data=segment_avg_units,x='LIFESTAGE',y='Average unit per customer',hue='PREMIUM_CUSTOMER')
# Out:
# <AxesSubplot: xlabel='LIFESTAGE', ylabel='Average unit per customer'>

# %% [markdown]
# **Old and young families buy more per customer**

# %%
segment_avg_price = merged_df.groupby(['PREMIUM_CUSTOMER','LIFESTAGE'])['TOT_SALES'].sum() / merged_df.groupby(['PREMIUM_CUSTOMER','LIFESTAGE'])['PROD_QTY'].sum()

# %%
segment_avg_price = pd.DataFrame(segment_avg_price,columns=['Average sales per unit'])

# %%
segment_avg_price.reset_index(inplace=True)

# %%
sns.barplot(data=segment_avg_price,x='LIFESTAGE',y='Average sales per unit',hue='PREMIUM_CUSTOMER')
plt.legend(loc='upper left')

# %% [markdown]
# **Mainstream midage and young singles/couples are more willing to pay more per pack.**

# %% [markdown]
# ## Affinity

# %%
tgt_custs = merged_df.loc[(merged_df['LIFESTAGE'] == 'YOUNG SINGLES/COUPLES') & (merged_df['PREMIUM_CUSTOMER'] == 'Mainstream'),:]
ntgt_custs = merged_df.loc[(merged_df['LIFESTAGE'] != 'YOUNG SINGLES/COUPLES') & (merged_df['PREMIUM_CUSTOMER'] != 'Mainstream'),:]

# %% [markdown]
# ### Brand

# %%
tgt_brand = tgt_custs.loc[:,['BRAND','PROD_QTY']]
tgt_prodqty  = tgt_brand['PROD_QTY'].sum()
tgt_brand = tgt_brand.groupby('BRAND')['PROD_QTY'].sum().reset_index()
tgt_brand.loc[:,'TGT_Brand_Affinity'] = tgt_brand['PROD_QTY'] / tgt_prodqty

# %%
ntgt_brand = ntgt_custs.loc[:,['BRAND','PROD_QTY']]
ntgt_prodqty  = ntgt_brand['PROD_QTY'].sum()
ntgt_brand = ntgt_brand.groupby('BRAND')['PROD_QTY'].sum().reset_index()
ntgt_brand.loc[:,'NTGT_Brand_Affinity'] = ntgt_brand['PROD_QTY'] / ntgt_prodqty

# %%
merged_brand_affinity = pd.merge(tgt_brand,ntgt_brand,left_index=True,right_index=True)
merged_brand_affinity = merged_brand_affinity[['BRAND_x','TGT_Brand_Affinity','NTGT_Brand_Affinity']]
merged_brand_affinity.rename(columns={'BRAND_x':'BRAND'},inplace=True)

# %%
merged_brand_affinity['Brand Affinity'] = merged_brand_affinity['TGT_Brand_Affinity'] / merged_brand_affinity['NTGT_Brand_Affinity']

# %%
merged_brand_affinity.sort_values(by='Brand Affinity',ascending=False).head()
# Out:
#        BRAND  TGT_Brand_Affinity  NTGT_Brand_Affinity  Brand Affinity
# 20  Tyrrells            0.029587             0.023968        1.234454
# 5     Dorito            0.014729             0.011986        1.228873
# 19  Twisties            0.043306             0.035355        1.224877
# 10    Kettle            0.185649             0.155243        1.195863
# 18  Tostitos            0.042581             0.035744        1.191269

# %% [markdown]
# <strong>Mainstream young couples/singles are more likely to buy Tyrrells compared to other brand.</strong>

# %% [markdown]
# ### Product size

# %%
tgt_size = tgt_custs.loc[:,['PROD_SIZE','PROD_QTY']]
tgt_prodqty = tgt_size['PROD_QTY'].sum()
tgt_size = tgt_size.groupby('PROD_SIZE')['PROD_QTY'].sum().reset_index()
tgt_size['TGT_PckSize_Affinity'] = tgt_size['PROD_QTY'] / tgt_prodqty

# %%
ntgt_size = ntgt_custs.loc[:,['PROD_SIZE','PROD_QTY']]
ntgt_prodqty = ntgt_size['PROD_QTY'].sum()
ntgt_size = ntgt_size.groupby('PROD_SIZE')['PROD_QTY'].sum().reset_index()
ntgt_size['NTGT_PckSize_Affinity'] = ntgt_size['PROD_QTY'] / ntgt_prodqty

# %%
merged_pcksize_affinity = pd.merge(tgt_size,ntgt_size,left_index=True,right_index=True)
merged_pcksize_affinity = merged_pcksize_affinity[['PROD_SIZE_x','TGT_PckSize_Affinity','NTGT_PckSize_Affinity']]
merged_pcksize_affinity.rename(columns={'PROD_SIZE_x':'PROD_SIZE'},inplace=True)

# %%
merged_pcksize_affinity['Product Size Affinity'] = merged_pcksize_affinity['TGT_PckSize_Affinity'] / merged_pcksize_affinity['NTGT_PckSize_Affinity']

# %%
merged_pcksize_affinity.sort_values(by='Product Size Affinity',ascending=False).head()
# Out:
#     PROD_SIZE  TGT_PckSize_Affinity  NTGT_PckSize_Affinity  \
# 17        270              0.029846               0.023366
# 20        380              0.030156               0.023964
# 19        330              0.057465               0.047511
# 2         110              0.099658               0.083489
# 4         134              0.111980               0.094240
#
#     Product Size Affinity
# 17               1.277295
# 20               1.258400
# 19               1.209522
# 2                1.193675
# 4                1.188241

# %% [markdown]
# <strong> More likely to purchase a product of 270 g</strong><br>
# Twisties is the only brand that offers 270 g product size

# %% [markdown]
# # Conclusion

# %% [markdown]
# - Sales are highest for: Budget older families, mainstream young singles/couples, mainstream retirees.
# - Most of the customers are from mainstream young singles/couples and retirees.
# - Mainstream young singles/couples are more likely to pay more per unit. Also more likely to purchase chips from <strong>Tyrrells</strong> and/or chips of size <strong>270 g</strong>.
